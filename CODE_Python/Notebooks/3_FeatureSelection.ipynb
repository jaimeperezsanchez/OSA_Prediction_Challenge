# %% [markdown]
# # Importing libraries

# %%
from IPython.display import display
import time
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing speech for male dataset

# %%
# Importing the df from excel file
file = 'OSA_propio_classification_speech.csv' #OSA_propio_classification.csv
df = pd.read_csv(file)
#df.set_index("Patient", inplace=True)
display(df)
print("\nStats based on OSA feature")
display(df.groupby('OSA').describe())
# Out:
#     Patient  Gender   Age   IAH  Cervical  Weight  Height    BMI   Smoker  \
# 0     P0005  hombre  32.0   9.0      40.0    80.0   173.0  26.73       no
# 1     P0006  hombre  32.0   2.0      42.0   109.0   190.0  30.19       no
# 2     P0007  hombre  39.0  34.0      42.0    86.0   169.0  30.11       no
# 3     P0008  hombre  47.0  60.0      44.0   145.0   172.0  49.01       no
# 4     P0013  hombre  36.0   3.7      40.0    90.0   180.0  27.78       ns
# ..      ...     ...   ...   ...       ...     ...     ...    ...      ...
# 169   P0400  hombre  61.0  32.0      39.0    85.0   177.0  27.13  antiguo
# 170   P0404  hombre  40.0  53.0      38.0    71.0   166.0  25.77       no
# 171   P0405  hombre  55.0   9.2      42.0    89.0   175.0  29.06       no
# 172   P0406  hombre  48.0   2.5      37.0    67.0   170.0  23.18       no
# 173   P0407  hombre  50.0  41.7      34.0    61.0   169.0  21.36       no
#
#     Snorer Illness      OSA      A_Form1      A_Form2      A_Form3  \
# 0       ns      si  Healthy   746.822118  1225.417574  2508.306857
# 1       ns      si  Healthy   741.095216  1194.912057  2535.047408
# 2       ns      si   Severe   681.116563  1345.969619  2647.407542
# 3       ns      si   Severe   732.652369  1307.902237  2605.230176
# 4       ns      ns  Healthy   741.800273  1414.064330  2420.678380
# ..     ...     ...      ...          ...          ...          ...
# 169     si      si   Severe   608.509815  1121.570720  2458.049557
# 170     si      si   Severe   655.871579  1153.428409  2581.684888
# 171     si      si  Healthy   648.894837  1225.945689  2675.378357
# 172     si      no  Healthy   753.004455  1304.270427  2558.809003
# 173     si      si   Severe  1011.583309  1465.404901  2501.913815
#
#          A_Form4    A_Ancho1    A_Ancho2    A_Ancho3    A_Ancho4     E_Form1  \
# 0    3775.739467  159.540487  136.262353  210.543171  310.282327  444.329416
# 1    4342.764233   82.978577   80.387144  169.240894  396.028693  447.590191
# 2    3547.479088  105.612767  292.676472  207.214787  496.932394  403.945565
# 3    3019.018221  202.704817  121.269657  230.876431  708.711232  437.415190
# 4    2829.912480  274.364652  142.593395  231.962809  946.517445  435.490170
# ..           ...         ...         ...         ...         ...         ...
# 169  3194.102527  120.443149  123.170911  107.460182  275.593915  464.842703
# 170  3623.254498   75.458584   89.725655  104.949696  249.018267  477.366208
# 171  3347.580154   61.461990  145.607515   76.011715  152.411836  392.014931
# 172  4043.968295  140.426482   92.186519  128.161148  643.642915  465.620852
# 173  3624.202634  257.682664  186.093433  108.066201  467.840924  462.538035
#
#          E_Form2      E_Form3      E_Form4    E_Ancho1    E_Ancho2  \
# 0    1923.198002  2413.099988  3702.694971   91.377736  180.722553
# 1    1854.870927  2393.710295  3113.232851   46.878312  128.777004
# 2    2013.252360  2641.697682  3668.224338   50.386443  201.033000
# 0    223.771504  328.075500  757.032914  2565.730496  3024.500134   74.718076
# 1    216.244108  337.409601  735.000000  2532.000000  4132.186568   68.657539
# 2     95.059357  370.154253  714.797758  2728.437822  3501.838315   92.078301
# 3    373.582142  303.000000  757.152778  2317.825661  4068.527272  197.000000
# 4    174.836713  287.000000  733.000000  2296.000000  2947.386531   74.000000
# ..          ...         ...         ...          ...          ...         ...
# 169   81.874651  357.350370  680.000000  2557.252429  3618.725195   61.552994
# 170  178.554697  357.002102  753.370470  2709.169879  3252.587119   86.355376
# 171   57.319194  338.000000  753.000000  2606.000000  3085.825882   50.000000
# 172  254.249225  395.113288  749.797888  2726.623633  3250.517227  101.694369
# 173  220.200068  337.006702  693.512274  2570.208670  3290.105093   62.102266
#
#        U_Ancho2    U_Ancho3    U_Ancho4
# 0     88.331369  128.496457  379.432142
# 1    192.000000  134.000000  264.337720
# 2    230.866726   87.218309  591.651748
# 3    134.369532  190.933843  144.054887
# 4    175.000000  274.000000  189.966079
# ..          ...         ...         ...
# 169   98.000000  320.037461   80.223743
# 170   58.411579   87.699868  145.780917
# 171  191.000000  157.000000  183.619478
# 172   78.179790   73.379515  103.298372
# 173  183.328668  117.796974  197.475209
#
# [174 rows x 52 columns]
# Stats based on OSA feature
#           Age                                                       IAH  \
#         count       mean        std   min   25%   50%   75%   max count
# OSA
# Healthy  91.0  44.054945  10.703439  25.0  36.0  42.0  53.0  71.0  91.0
# Severe   83.0  49.096386  11.536384  32.0  40.0  48.0  56.5  78.0  83.0
#
#                                                              Cervical  \
#               mean        std   min   25%   50%    75%   max    count
# OSA
# Healthy   5.052747   2.898518   0.0   2.8   5.0   7.75  10.0     91.0
# Severe   46.370602  14.478314  30.0  34.5  43.0  54.80  87.0     83.0
#
#                                                            Weight              \
#               mean       std   min   25%   50%   75%   max  count        mean
# OSA
# Healthy  41.087912  2.644274  35.0  40.0  41.0  43.0  50.0   91.0   87.076923
# Severe   44.036145  3.637360  34.0  42.0  44.0  46.0  53.0   83.0  100.638554
#
#                                                    Height              \
#                std   min   25%   50%    75%    max  count        mean
# OSA
# Healthy  13.359334  67.0  79.0  86.0   92.5  140.0   91.0  175.692308
# Severe   21.055431  61.0  85.0  98.0  111.0  162.0   83.0  176.156627
#
#                                                        BMI             \
#               std    min    25%    50%    75%    max count       mean
# OSA
# Healthy  7.262831  160.0  170.0  175.0  180.0  191.0  91.0  28.230989
# Severe   6.690878  159.0  171.5  176.0  180.0  197.0  83.0  32.333614
#
#                                                      A_Form1              \
#               std    min    25%    50%    75%    max   count        mean
# OSA
# Healthy  4.125021  22.84  25.45  27.17  30.10  43.43    91.0  705.989810
# Severe   6.121971  21.36  28.24  31.31  35.18  52.30    83.0  697.107962
#
#                                                                     \
#                std         min         25%         50%         75%
# OSA
# Healthy  55.486424  556.597276  655.653551  713.096404  745.819894
# Severe   70.366757  586.449988  651.078942  686.841203  728.507659
#
#                      A_Form2                                       \
#                  max   count         mean        std          min
# OSA
# Healthy   825.003594    91.0  1262.173376  84.853776  1077.025904
# Severe   1011.583309    83.0  1255.109952  91.127139   990.000000
#
#                                                             A_Form3  \
#                  25%          50%          75%          max   count
# OSA
# Healthy  1203.045925  1257.088559  1318.951522  1463.749859    91.0
# Severe   1189.819925  1265.714435  1323.941413  1465.404901    83.0
#
#                                                                          \
#                 mean         std          min          25%          50%
# OSA
# Healthy  2449.672486  217.118492  1894.000000  2345.597963  2448.922421
# Severe   2451.056302  174.452336  1996.544846  2359.773069  2439.460580
#
#                              A_Form4                                       \
#                  75%     max   count         mean         std         min
# OSA
# Healthy  2534.272307  3426.0    91.0  3699.784505  380.056301  2829.91248
# Severe   2562.327795  2875.0    83.0  3637.801616  429.338433  2627.25256
#
#                                                             A_Ancho1  \
#                  25%          50%          75%          max    count
# OSA
# Healthy  3435.982269  3665.096890  3935.081587  4628.643829     91.0
# Severe   3384.236386  3582.718561  3856.264003  4631.501520     83.0
#
#                                                                               \
#                mean        std        min        25%         50%         75%
# OSA
# Healthy  137.146451  67.966100  34.197772  96.371769  117.883817  156.698204
# Severe   133.384387  67.225834  34.141500  86.453865  122.906956  169.238526
#
#                     A_Ancho2                                                \
#                 max    count        mean         std        min        25%
# OSA
# Healthy  446.050677     91.0  127.888136   42.029698  64.392530   92.76976
# Severe   447.146702     83.0  166.443640  117.243857  49.173029  111.69969
#
#                                        A_Ancho3                          \
#                 50%         75%    max    count        mean         std
# OSA
# Healthy  117.778299  153.681451  261.0     91.0  195.614513  175.413730
# Severe   140.833975  188.011258  994.0     83.0  182.717941  102.356154
#
#                                                                A_Ancho4  \
#                min         25%         50%         75%     max    count
# OSA
# Healthy  25.957502  117.107769  160.674167  227.596833  1650.0     91.0
# Severe   56.911559  114.854013  157.823765  218.864786   750.0     83.0
#
#                                                                     \
#                mean         std        min         25%         50%
# OSA
# Healthy  357.586769  189.394838  63.037195  212.267860  334.990255
# Severe   332.156106  172.090990  56.076270  206.482373  303.566674
#
#                                  E_Form1                                     \
#                 75%          max   count        mean        std         min
# OSA
# Healthy  441.557266  1049.474371    91.0  441.465397  36.295125  341.201533
# Severe   409.981306   800.848246    83.0  445.051044  30.913405  354.000000
#
#                                                         E_Form2               \
#                 25%         50%         75%         max   count         mean
# OSA
# Healthy  417.883039  440.187931  464.979782  547.195927    91.0  1890.859505
# Severe   424.856290  444.597748  466.687884  529.118655    83.0  1869.057051
#
#                                                                          \
#                 std          min          25%          50%          75%
# OSA
# Healthy  114.367105  1560.788827  1807.155428  1900.140958  1965.701807
# Severe   130.180292  1637.713695  1761.479491  1869.924230  1958.108914
#
#                      E_Form3                                        \
#                  max   count         mean         std          min
# OSA
# Healthy  2190.360817    91.0  2477.653141  143.077537  2138.498634
# Severe   2229.231935    83.0  2466.139089  139.426187  2126.296503
#
#                                                             E_Form4  \
#                  25%          50%          75%          max   count
# OSA
# Healthy  2391.945149  2458.278165  2585.202596  2856.835451    91.0
# Severe   2404.000000  2465.019641  2565.257029  2759.854478    83.0
#
#                                                                          \
#                 mean         std          min          25%          50%
# OSA
# Healthy  3512.155015  344.789563  2668.962601  3334.828050  3515.047852
# Severe   3570.927628  411.279975  2922.187274  3287.313751  3511.728821
#
#                                   E_Ancho1                                   \
#                  75%          max    count       mean        std        min
# OSA
# Healthy  3644.830042  4571.832751     91.0  76.447835  39.797525  19.340031
# Severe   3740.024035  4687.776855     83.0  71.454798  35.452642  19.788778
#
#                                                 E_Ancho2              \
#                25%        50%        75%    max    count        mean
# OSA
# Healthy  45.273121  65.597030  94.161597  263.0     91.0  115.125534
# Severe   44.600594  64.075466  87.369536  187.0     83.0  105.441392
#
#                                                                                \
#                 std        min        25%        50%         75%          max
# OSA
# Healthy  152.792657  40.454148  69.679282  86.231219  122.107406  1484.738819
# Severe    56.319688  36.862283  70.772240  86.473331  123.185856   340.000000
#
#         E_Ancho3                                                           \
#            count        mean        std       min         25%         50%
# OSA
# Healthy     91.0  186.837175  97.316924  55.91602  133.830105  167.637603
# Severe      83.0  165.751927  90.244428  60.44936  111.990543  136.607616
#
#                               E_Ancho4                                     \
#                 75%       max    count        mean         std        min
# OSA
# Healthy  214.742284  744.1342     91.0  286.375783  151.008894  44.463286
# Severe   193.682047  589.0000     83.0  267.636872  152.735404  70.437811
#
#                                                         I_Form1              \
#                 25%         50%         75%         max   count        mean
# OSA
# Healthy  175.666266  259.907245  328.444089  793.591996    91.0  298.208023
# Severe   170.044812  232.740020  332.588321  755.700057    83.0  304.701546
#
#                                                                     \
#                std         min         25%         50%         75%
# OSA
# Healthy  33.353221  229.408355  275.330060  294.458078  318.488595
# Severe   35.866150  203.398283  280.161918  300.617996  325.547316
#
#                     I_Form2                                        \
#                 max   count         mean         std          min
# OSA
# Healthy  401.708619    91.0  2185.351567  135.419023  1761.730406
# Severe   411.859394    83.0  2168.989939  163.999683  1761.890829
#
#                                                            I_Form3  \
#                  25%          50%          75%         max   count
# OSA
# Healthy  2094.667284  2191.123804  2271.570644  2555.18055    91.0
# Severe   2061.895983  2184.490076  2264.620448  2570.00000    83.0
#
#                                                                          \
#                 mean         std          min          25%          50%
# OSA
# Healthy  2719.398494  187.084887  2232.146884  2582.704501  2697.613705
# Severe   2662.728690  149.983872  2304.119119  2553.161826  2654.000000
#
#                                   I_Form4                           \
#                  75%          max   count         mean         std
# OSA
# Healthy  2840.772432  3333.636340    91.0  3554.374254  327.910660
# Severe   2777.768579  3036.972577    83.0  3664.949707  396.883577
#
#                                                                           \
#                  min          25%          50%          75%          max
# OSA
# Healthy  2763.923735  3332.264168  3556.005223  3718.093387  4388.222412
# Severe   2973.786710  3337.274323  3608.392365  3898.448619  4527.438416
#
#         I_Ancho1                                                        \
#            count       mean        std       min        25%        50%
# OSA
# Healthy     91.0  54.112127  30.216643  6.582473  36.880286  48.798739
# Severe      83.0  52.660586  22.884013  5.501548  35.924302  49.710416
#
#                                I_Ancho2                                     \
#                75%         max    count        mean         std        min
# OSA
# Healthy  65.387129  258.087131     91.0  110.446032  149.007447  32.841525
# Severe   61.312945  124.323504     83.0   91.063240   35.083217  30.828080
#
#                                                        I_Ancho3              \
#                25%        50%         75%          max    count        mean
# OSA
# Healthy  61.168190  83.039387  110.155991  1362.898725     91.0  234.214711
# Severe   65.045851  88.460101  111.520987   192.930901     83.0  222.043292
#
#                                                                             \
#                 std        min         25%         50%         75%     max
# OSA
# Healthy  188.827751  63.238225  145.309554  193.995987  259.999071  1570.0
# Severe   167.531788  65.090593  134.585588  194.214985  253.406119  1425.0
#
#         I_Ancho4                                                             \
#            count        mean         std        min         25%         50%
# OSA
# Healthy     91.0  220.637666  111.410054  60.722711  135.560342  189.115314
# Severe      83.0  219.700924  104.887778  62.982612  152.457721  193.337910
#
#                                 O_Form1                                     \
#                 75%         max   count        mean        std         min
# OSA
# Healthy  269.751799  561.145002    91.0  480.078062  45.472539  370.102129
# Severe   257.892563  549.277808    83.0  480.251536  41.170716  368.914547
#
#                                                         O_Form2              \
#                 25%         50%         75%         max   count        mean
# OSA
# Healthy  450.721623  481.211222  514.833478  597.375762    91.0  855.675597
# Severe   450.833762  480.924243  510.579243  570.314676    83.0  850.424505
#
#                                                                    \
#               std         min         25%         50%         75%
# OSA
# Healthy  80.68062  668.048051  803.307980  858.882948  915.318128
# Severe   67.07423  632.040255  811.549677  852.146145  900.969821
#
#                      O_Form3                                       \
#                  max   count         mean         std         min
# OSA
# Healthy  1014.260141    91.0  2458.623182  186.895056  2067.88307
# Severe    982.782174    83.0  2519.107064  216.020498  1820.00000
#
#                                                             O_Form4  \
#                  25%          50%          75%          max   count
# OSA
# Healthy  2323.047886  2458.905038  2564.119994  2981.322629    91.0
# Severe   2384.798233  2526.373251  2674.810116  2972.106528    83.0
#
#                                                                          \
#                 mean         std          min          25%          50%
# OSA
# Healthy  3367.516111  302.061443  2838.283888  3179.402094  3328.722067
# Severe   3420.109691  401.700712  2855.838626  3162.238056  3296.333035
#
#                                   O_Ancho1                                    \
#                  75%          max    count        mean        std        min
# OSA
# Healthy  3490.478008  4431.443848     91.0  100.632769  46.282591  25.360149
# Severe   3527.641428  4618.069159     83.0   91.971762  44.128370  23.290696
#
#                                                  O_Ancho2              \
#                25%        50%         75%    max    count        mean
# OSA
# Healthy  67.637280  93.005553  118.870430  272.0     91.0  111.721675
# Severe   64.282406  83.171419  109.436109  338.0     83.0  117.328600
#
#                                                                               \
#                std        min        25%         50%         75%         max
# OSA
# Healthy  59.803854  22.257356  80.589496   96.343217  124.346196  400.000000
# Severe   75.428469  36.834633  71.678055  101.886015  130.242463  459.333096
#
#         O_Ancho3                                                           \
#            count        mean        std        min        25%         50%
# OSA
# Healthy     91.0  139.494409  91.679174  42.891215  80.754591  104.982354
# Severe      83.0  133.818843  83.038285  34.961274  81.088179  109.883163
#
#                            O_Ancho4                                    \
#                 75%    max    count        mean        std        min
# OSA
# Healthy  164.435377  564.0     91.0  187.717939  114.36889  38.252462
# Severe   162.942080  483.0     83.0  185.171091  110.62240  59.217254
#
#                                                         U_Form1              \
#                 25%         50%         75%         max   count        mean
# OSA
# Healthy  108.821276  162.665720  234.075020  700.631092    91.0  334.313160
# Severe   107.927746  160.299966  228.103611  684.736083    83.0  332.440572
#
#                                                                            \
#                std         min         25%         50%         75%    max
# OSA
# Healthy  38.127686  246.227161  305.899629  330.000000  354.263106  460.0
# Severe   39.439290  235.238202  304.135691  333.382396  364.152105  440.0
#
#         U_Form2                                                             \
#           count        mean        std         min         25%         50%
# OSA
# Healthy    91.0  742.323510  74.564056  567.558334  694.483034  750.215625
# Severe     83.0  729.726898  78.523396  507.000000  684.323086  733.000000
#
#                                 U_Form3                                        \
#                 75%         max   count         mean         std          min
# OSA
# Healthy  777.710014  981.209781    91.0  2388.699191  164.047776  2063.902403
# Severe   780.223456  942.000000    83.0  2440.041297  180.699339  2064.000000
#
#                                                             U_Form4  \
#                  25%          50%          75%          max   count
# OSA
# Healthy  2290.778728  2369.485793  2513.830070  2738.835049    91.0
# Severe   2317.912830  2421.113480  2567.639395  2853.782431    83.0
#
#                                                                          \
#                 mean         std          min          25%          50%
# OSA
# Healthy  3398.274086  412.538107  2692.860497  3100.842879  3337.289175
# Severe   3375.048498  449.913988  2789.340314  3030.367024  3252.542519
#
#                                   U_Ancho1                                   \
#                  75%          max    count       mean        std        min
# OSA
# Healthy  3679.253401  4450.556152     91.0  60.667778  27.469216   3.855779
# Severe   3577.698623  4539.745337     83.0  62.502147  30.345839  10.848148
#
#                                                     U_Ancho2              \
#                25%        50%       75%         max    count        mean
# OSA
# Healthy  38.895684  56.246568  75.32582  142.752883     91.0  111.905123
# Severe   40.489872  58.293837  76.38021  197.000000     83.0  127.226466
#
#                                                                          \
#                 std        min        25%        50%         75%    max
# OSA
# Healthy   76.430451  17.161040  57.296980  94.333712  152.290261  504.0
# Severe   105.585075  12.891995  64.492133  99.000000  151.492111  721.0
#
#         U_Ancho3                                                             \
#            count        mean         std        min         25%         50%
# OSA
# Healthy     91.0  150.949679   79.392394  35.864257   89.743291  136.912946
# Severe      83.0  162.955859  103.653295  39.774160  100.188304  128.312096
#
#                            U_Ancho4                                     \
#                 75%    max    count        mean         std        min
# OSA
# Healthy  192.643023  394.0     91.0  186.233697  108.822714  25.217470
# Severe   197.978940  712.0     83.0  179.411156  118.455382  26.952545
#
#
#                 25%         50%         75%         max
# OSA
# Healthy  110.785473  162.374451  219.699729  511.275112
# Severe    94.578468  154.262586  212.121525  591.651748

# %% [markdown]
# # Filter: Heatmaps

# %%
#Global
plt.figure(figsize=(12,12))
hm = sns.heatmap(df.corr(),cmap="RdYlGn", annot=False)
bottom, top = hm.get_ylim()
hm.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
#Local
filtered_columns = list()
substring_matching = ["A_", "E_", "I_", "O_", "U_",
                      "Form", "Ancho",
                      "1", "2","3","4"]

for substring in substring_matching:
    filtered = list(filter(lambda x: substring in x, df.columns))
    filtered_columns.append(filtered)
    
for col in filtered_columns:
    plt.figure(figsize=(12,12))
    hm = sns.heatmap(df[col].corr(),cmap="RdYlGn", annot=False)
    bottom, top = hm.get_ylim()
    hm.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()

# %% [markdown]
# # Filter: Univariate Selection
# https://towardsdatascience.com/feature-selection-techniques-in-machine-learning-with-python-f24e7da3f36e

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#Selecting features for the model
X = df.drop(["IAH","OSA","Patient"],axis=1)
X = pd.get_dummies(X, 
                   drop_first=False,
                   columns=["Gender","Smoker","Snorer","Illness"])
y = df["OSA"]


#Applying SelectKBest to extract the 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)

#Concatenating dataframes for better visualization
dfscores = pd.DataFrame(fit.scores_)
dfpvalues = pd.DataFrame(fit.pvalues_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores, dfpvalues],axis=1)
featureScores.columns = ['Feature','Score',"p-values"]

#Printing and plotting the best features
display(featureScores.sort_values("Score",ascending=False).head(10))

for col in ["Score","p-values"]:
    plt.figure(figsize=(15,10))
    ax = sns.barplot(x='Feature', y=col, data=featureScores, palette="Set2")
    ax.set_xticklabels(featureScores['Feature'],rotation=90)
    plt.show
# Out:
#      Feature       Score      p-values
# 10  A_Ancho2  441.122676  6.167504e-98
# 26  I_Ancho2  161.146725  6.354890e-37
# 24   I_Form4  147.138764  7.318075e-34
# 19  E_Ancho3  109.168247  1.490793e-25
# 42  U_Ancho2   85.474812  2.346719e-20
# 2     Weight   85.343211  2.508217e-20
# 12  A_Ancho4   81.262991  1.975924e-19
# 31   O_Form3   63.839706  1.349657e-15
# 20  E_Ancho4   54.940724  1.242203e-13
# 23   I_Form3   51.777312  6.216601e-13

# %% [markdown]
# # Wrapper: Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

rfe_selector = RFE(estimator=LogisticRegression(solver='liblinear'),
                   n_features_to_select=5,
                   step=10
                  )
rfe_selector.fit(X, y)

rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
ranking = sorted(zip(rfe_selector.ranking_, X.columns))

print("Top features:")
for feature in ranking[:20]:
    print(feature)
# Out:
# Top features:
# (1, 'BMI')
# (1, 'Smoker_antiguo')
# (1, 'Snorer_no')
# (1, 'Snorer_ns')
# (1, 'Snorer_si')
# (2, 'Smoker_si')
# (3, 'Age')
# (3, 'Cervical')
# (3, 'Height')
# (3, 'Illness_no')
# (3, 'Illness_ns')
# (3, 'Illness_si')
# (3, 'Smoker_no')
# (3, 'Smoker_ns')
# (3, 'U_Form1')
# (3, 'Weight')
# (4, 'A_Ancho1')
# (4, 'A_Ancho2')
# (4, 'A_Form1')
# (4, 'E_Form1')

# %%
#RFE with CV
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

#SVC IS REALLY SLOW!!!
# Creating the RFE object and computing a cross-validated score.
rfecv = RFECV(estimator=LogisticRegression(solver='liblinear'),
              step=1,
              cv=StratifiedKFold(10),
              scoring='accuracy',
              verbose=0,
             )
rfecv.fit(X, y)

rfe_support = rfecv.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
ranking = sorted(zip(rfecv.ranking_, X.columns))

print("Optimal number of features: %d" % rfecv.n_features_)
print("Top features:")
for feature in ranking[:rfecv.n_features_]:
    print(feature)

plt.figure(figsize=(15,10))
sns.set()
ax = sns.lineplot(x=range(1, len(rfecv.grid_scores_) + 1), y=rfecv.grid_scores_, palette="Set2")
ax.set(xlabel='Number of Features',
       ylabel='CV Score (Accuracy)')
plt.show()
# Out:
# Optimal number of features: 20
# Top features:
# (1, 'A_Ancho2')
# (1, 'Age')
# (1, 'BMI')
# (1, 'Cervical')
# (1, 'E_Form1')
# (1, 'Gender_hombre')
# (1, 'Height')
# (1, 'I_Form1')
# (1, 'Illness_no')
# (1, 'Illness_ns')
# (1, 'Illness_si')
# (1, 'Smoker_antiguo')
# (1, 'Smoker_no')
# (1, 'Smoker_ns')
# (1, 'Smoker_si')
# (1, 'Snorer_no')
# (1, 'Snorer_ns')
# (1, 'Snorer_si')
# (1, 'U_Form1')
# (1, 'Weight')

# %% [markdown]
# # Embedded: Feature Importance
# https://towardsdatascience.com/the-5-feature-selection-algorithms-every-data-scientist-need-to-know-3a6b566efd2

# %%
from sklearn.ensemble import ExtraTreesClassifier

#Using inbuilt class feature_importances of tree based classifiers
model = ExtraTreesClassifier()
model.fit(X,y)

#Creating dataset of feature importances for better visualization
dfimportance = pd.DataFrame(model.feature_importances_)
dfcolumns = pd.DataFrame(X.columns)
feat_importances = pd.concat([dfcolumns,dfimportance],axis=1)
feat_importances.columns = ['Feature','Importance']

#Displaying it
display(feat_importances.sort_values("Importance",ascending=False).head(10))

plt.figure(figsize=(15,10))
ax = sns.barplot(x='Feature', y='Importance', data=feat_importances, palette="Set2")
ax.set_xticklabels(feat_importances['Feature'],rotation=90)
plt.show
# Out:
# /home/sergio/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#      Feature  Importance
# 1   Cervical    0.074293
# 4        BMI    0.049752
# 2     Weight    0.038063
# 0        Age    0.030546
# 24   I_Form4    0.026214
# 8    A_Form4    0.025381
# 39   U_Form3    0.023643
# 29   O_Form1    0.023059
# 44  U_Ancho4    0.022720
# 35  O_Ancho3    0.022714
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Embedded: Select from Model

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Xnorm = scaler.fit_transform(X)

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1"),
                                      max_features=5)
embeded_lr_selector.fit(Xnorm, y)

embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
for feature in embeded_lr_feature:
    print(feature)
# Out:
# Age
# Weight
# A_Ancho2
# U_Form1
# Snorer_no
# /home/sergio/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# # Dimensionality Reduction: PCA
# https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %%
from sklearn.decomposition import PCA

scaler = StandardScaler()
Xnorm = scaler.fit_transform(X)

pca = PCA(50) 
Xnorm_pca = pca.fit_transform(Xnorm)

plt.figure(figsize=(15,10))
sns.set()
ax = sns.lineplot(x=list(range(50)),
                  y=np.cumsum(pca.explained_variance_ratio_),
                  palette="Set2")
ax.set(xlabel='Number of Components',
       ylabel='Cumulative Explained variance')
plt.show()

# %%
pca = PCA(3) 
Xnorm_pca = pca.fit_transform(Xnorm)

df['pca-one'] = Xnorm_pca[:,0]
df['pca-two'] = Xnorm_pca[:,1] 
df['pca-three'] = Xnorm_pca[:,2]

print('Number of components: ' + str(pca.n_components_))
print('Explained variation per principal component:\n' + str(pca.explained_variance_ratio_))

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="OSA",
    palette="Set2",
    data=df,
    s=300
)

import plotly.express as px

fig = px.scatter_3d(df,
                    x='pca-one',
                    y='pca-two',
                    z='pca-three',
                    color='OSA',
                    color_discrete_sequence=[
                        "rgb(0, 100, 0)",
                        "rgb(255, 140, 0)"
                    ],
                   )
fig.update_traces(marker=dict(size=3))
fig.show()
# Out:
# Number of components: 3
# Explained variation per principal component:
# [0.08956442 0.06821963 0.0560361 ]
# <div>
#
#
#             <div id="dade690d-074b-48a8-8755-c4c302e2cfa2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
6093309119408855, 3.1327192500085723, 2.5081059789307902, -0.36103902165913304, 2.7450199476328003, 2.04208264911442, 1.7505916432664108, 1.984868570457125, 0.03583484411977366, 0.8158508104722423, 1.1133614252447857, -0.6799017200862727, -1.2153287101053176, 2.237203582029374, -1.3582969440676418, -2.8142704482192427, 2.1675054175137265, -0.6897809838225061, -0.6093309119408855, 0.5683208515274268, -1.7719420964605486, -2.1369998469144194, -2.1959042014558436, -2.5263446463863297, -2.1446234106084012, 1.3939893632875444, 1.2118488938124006, 0.38558686925921015, -0.2057899845240733, -1.3868760757879726, -2.037910015201488, -2.1044934817805987, -1.1199591715585715, -1.2735312632004367, -1.0076851199944479, -0.6870761331074211, -0.16813467749017552, -0.463892529319526, -1.0835351156460526, -0.21333913777633062, -2.6429367293900072, -2.67941092007104, -0.9825704651061327, 0.2632137313409495, -2.511969640263838, -2.1714366833427348, 0.1830651444229046, -0.3666145092025278, -1.5468710504617578, -0.1527072929768642, -1.8086989983168245, -1.7600048543880527, -2.2408374054761144, -0.12319714592278781, 2.6446135260597083, -0.7686576058022 ...

# %% [markdown]
# # Visualization: t-SNE

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(Xnorm[:,:5])

df['tsne-2d-one'] = tsne_results[:,0]
df['tsne-2d-two'] = tsne_results[:,1]

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="OSA",
    palette="Set2",
    data=df,
    s=300
)


tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(Xnorm[:,:5])

df['tsne-3d-one'] = tsne_results[:,0]
df['tsne-3d-two'] = tsne_results[:,1]
df['tsne-3d-three'] = tsne_results[:,2]

fig = px.scatter_3d(df,
                    x='tsne-2d-one',
                    y='tsne-2d-two',
                    z='tsne-2d-three',
                    color='OSA',
                    color_discrete_sequence=[
                        "rgb(0, 100, 0)",
                        "rgb(255, 140, 0)"
                    ],
                   )
fig.update_traces(marker=dict(size=3))
fig.show()
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 174 samples in 0.000s...
# [t-SNE] Computed neighbors for 174 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 174 / 174
# [t-SNE] Mean sigma: 1.055277
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.497643
# [t-SNE] KL divergence after 300 iterations: 0.462082
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 174 samples in 0.000s...
# [t-SNE] Computed neighbors for 174 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 174 / 174
# [t-SNE] Mean sigma: 1.055277
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 98.291985
# [t-SNE] KL divergence after 300 iterations: 2.386126
# <div>
#
#
#             <div id="10fa927c-842d-49f2-880f-20bd096ea93a" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10fa927c-842d-49f2-880f-20bd096ea93a")) {
#                     Plotly.newPlot(
#                         '10fa927c-842d-49f2-880f-20bd096ea93a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "OSA=Healthy<br>tsne-2d-one=%{x}<br>tsne-2d-two=%{y}<br>tsne-2d-three=%{z}", "legendgroup": "OSA=Healthy", "marker": {"color": "rgb(0, 100, 0)", "size": 3, "symbol": "circle"}, "mode": "markers", "name": "OSA=Healthy", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1.5473661422729492, -3.0333759784698486, -3.370408058166504, 4.417047023773193, -4.798233985900879, -6.434871196746826, -2.6213958263397217, -4.780213356018066, -4.965151786804199, -1.4347219467163086, -6.939788818359375, -7.301219940185547, -3.2182979583740234, -2.0732033252716064, 0.6241815090179443, -5.146754264831543, -3.6240248680114746, 3.4114444255828857, -3.6531014442443848, 0.03353309631347656, -